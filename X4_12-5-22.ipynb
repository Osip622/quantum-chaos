# %%
import matplotlib.pyplot as plt
import numpy as np
import sdeint
import math
import warnings
warnings.filterwarnings("ignore")
g = 0.3
ω = np.pi/3
β = 0.005
Γ = 0
ϕ = 0
hbar = 1


# main function (including dissipation)
def f(t,y):
    x = y[0]
    p = y[1]
    χ = y[2]
    Π = y[3]
    sr = y[4]
    si = y[5]
    #V= -0.5*x**2+ 0.25*β*x**4
    f0 = p
    f1 = -β ** 2 * x ** 3  - 2 * Γ * p - 3*x*β**2*χ**2#+g*np.cos(ω * t)/β-x - 
    f2 = Π + Γ * ((χ - χ ** 3 + χ * Π ** 2 - 1 / (4 * χ)) * np.cos(2*ϕ) - Π * (-1 + 2*χ**2) * np.sin(2*ϕ) + χ - χ**3 - χ*Π**2 + 1/(4*χ))
    f3 = -χ * (1 - 3 * β ** 2 * (-x ** 2 + χ ** 2)) + 1 / (4 * χ ** 3) + Γ * ((Π ** 3 - Π + 3 * Π / (4 * χ ** 2) - Π * χ ** 2) * np.cos(2 * ϕ) - (-1 / (4 * χ ** 3) + 1 / χ - χ + 2 * χ * Π ** 2) * np.sin(2 * ϕ) + (-Π ** 3 - Π - 3 * Π / (4 * χ ** 2) - Π * χ ** 2))
    #f4 = p**2+0.5*(Π*(Π + Γ * ((χ - χ ** 3 + χ * Π ** 2 - 1 / (4 * χ)) * np.cos(2*ϕ) - Π * (-1 + 2*χ**2) * np.sin(2*ϕ) + χ - χ**3 - χ*Π**2 + 1/(4*χ)))-χ*(χ * (1 - 3 * β ** 2 * (x ** 2 + χ ** 2)) + 1 / (4 * χ ** 3) + Γ * ((Π ** 3 - Π + 3 * Π / (4 * χ ** 2) - Π * χ ** 2) * np.cos(2 * ϕ) - (-1 / (4 * χ ** 3) + 1 / χ - χ + 2 * χ * Π ** 2) * np.sin(2 * ϕ) + (-Π ** 3 - Π - 3 * Π / (4 * χ ** 2) - Π * χ ** 2))))-0.5*p**2-0.5*Π ** 2+0.5*x**2-0.25*β**2*x**4-0.75*β**2*χ ** 4+0.5*χ **2 - 1/(8*χ ** 2)-1.5*β**2*x**2*χ**2#E from new paper
    f4=1/(χ)**2*(-0.25-0.25*Γ*np.cos(ϕ) *np.sin(ϕ) +χ*(Γ*np.cos(ϕ) *np.sin(ϕ)*Π**2*χ+Γ*Π*(0.5-0.5*np.cos(2*ϕ)+(1+np.cos(2*ϕ))+χ+χ*p**2-β**2*x**4+1.5*β**2*χ**4+Γ*np.cos(ϕ) *np.sin(ϕ)*(1-χ**2))))#+g*x*np.cos(ω * t)/β+0.5*x**2
     
    f5 = 1j*np.log(χ)
    return np.array([f0, f1, f2, f3, f4, f5])

# %%
from scipy.integrate import odeint
from scipy.integrate import complex_ode
from scipy.integrate import solve_ivp
X=[1,0.8,0.2,0.1,0.1,1j]
t0=0
tf=200
#def solve_it(k):
t_eval_arr = []
for i in range(tf):
    t_eval_arr.append(2*np.pi*i)
#print(t_eval_arr)
#t_eval_arr = np.array(t_eval_arr)
sol=solve_ivp(f, [t0, 2*tf*np.pi], X, t_eval=t_eval_arr)

# %%
sol_ar=sol.y.T

# %%
len(sol_ar)
# Out:
# 200

# %%
sol_ar[1][1]
# Out:
# (0.7845807770506177+0j)

# %%
x_list=[]
for i in range(len(sol_ar)):
    x_list.append(float(sol_ar[i][0]))
plt.plot(sol.t,x_list)

# %%
p_list=[]
for i in range(len(sol_ar)):
    p_list.append(float(sol_ar[i][1]))
plt.plot(sol.t,p_list)

# %%
chi_list=[]
for i in range(len(sol_ar)):
    chi_list.append(float(sol_ar[i][2]))
plt.plot(sol.t,chi_list)

# %%
plt.plot(x_list,p_list)

# %%
pi_list=[]
for i in range(len(sol_ar)):
    pi_list.append(float(sol_ar[i][3]))
plt.plot(sol.t,pi_list)

# %%
sr_list=[]
for i in range(len(sol_ar)):
    sr_list.append(float(sol_ar[i][4]))
plt.plot(sol.t,np.array(sr_list))

# %%
si_list=[]
for i in range(len(sol_ar)):
    si_list.append(sol_ar[i][5])
plt.plot(sol.t,np.imag(si_list))

# %%
import math

# %%
def integral(xt,x0,pt,p0,chit,chi0,pit,pi0, srt, sit, sr0,si0):
    A0=pi0/(2*chi0)-1j/(4*chi0**2)
    At=pit/(2*chit)+1j/(4*chit**2)
    s0=sr0+1j*si0
    st=1j*sit
    #print(A0-At)
    return (1/(np.sqrt(1/chi0**2 + (2*1j*pi0)/chi0 + (1 - 2*1j*chit*pit)/chit**2)))*2 *np.exp((-((1j*(2*chi0*pi0*(4*chit**2*pt + 1j*(x0 - xt) + 2*chit*pit*(x0 - xt))*(x0 - xt)+(x0 - xt)*(-4*1j*chit**2*pt + x0 - 2*1j*chit*pit*(x0 - xt) - xt) + 4*chi0**2*(chit**2*(p0 - pt)**2 - 1j*p0*(x0 - xt) + 2*chit*p0*pit*(-x0 + xt))))/(4*1j*chit**2 - 8*chi0*chit**2*pi0 + chi0**2 *(4*1j + 8* chit* pit)))))*np.sqrt(np.pi)*np.exp(1j*(math.fmod(srt+sr0,2*np.pi)+math.fmod(sit+si0,2*np.pi)))
           # *np.exp(1j*(math.fmod(srt+sr0,2*np.pi)+math.fmod(sit+si0,2*np.pi)))
#np.exp(-1j*np.pi/4)*np.exp(1j*(s0+st))/(np.sqrt(A0-At))

# %%
integration_l=[]
for i in range(len(sol_ar)):
    x=sol_ar[i][0]
    x0=X[0]
    p=sol_ar[i][1]
    p0=X[1]
    chi=sol_ar[i][2]
    chi0=X[2]
    pi=sol_ar[i][3]
    pi0=X[3]
    sr=sol_ar[i][4]
    si=sol_ar[i][5]
    sr0=X[4]
    si0=X[5]
    
    integration_l.append(integral(x,x0,p,p0,chi,chi0,pi,pi0, sr, si, sr0,si0))

# %%
integration_l
# Out:
# [(0.4913325190075402+0.09959803237458398j),
#  (3.919118115744546e-35-1.6133001441046415e-35j),
#  (3.3548097443424506e-128+2.7477518846816673e-127j),
#  (-2.4812168616030992e-213-7.789087006320916e-213j),
#  (-1.3753323966626667e-193+4.1114517176212294e-193j),
#  (-2.216319167522022e-106-2.4637345613567574e-105j),
#  (2.2327934922704343e-36-3.8166427091520555e-36j),
#  (-0.0008149799599012244+0.0002773278508538853j),
#  (5.5825129862556245e-09+1.2988961180877615e-07j),
#  (-2.474944335385799e-47+1.5068975597708098e-48j),
#  (1.366568410608024e-102+8.721922785656025e-103j),
#  (9.829226719664429e-123-9.805883611335408e-123j),
#  (6.205161709215737e-91+4.0701908240995646e-91j),
#  (1.7306717243029554e-48+5.2355542437058256e-49j),
#  (2.108960503912036e-18-5.801041736596743e-18j),
#  (0.0014339131395746765+0.005631269336345874j),
#  (-0.002992862191170887-0.016821108940510338j),
#  (6.929807980066092e-16-3.665742094794778e-17j),
#  (1.193315820714321e-34-2.010167416203613e-34j),
#  (-2.636703383327878e-40-1.4987046870974578e-40j),
#  (-1.7952673582470088e-29+2.5033000196661255e-29j),
#  (3.1751289251366967e-14-1.2059546211240445e-14j),
#  (-0.00020232102889112353+0.0003208738046746975j),
#  (-0.44821941255746933+0.4782934073997205j),
#  (-2.436167221887806e-05-0.00012133257560169352j),
#  (-3.594889699751755e-15-1.8860534032130257e-14j),
#  (-2.1024467124708453e-24+9.95727375185641e-25j),
#  (1.9233583582608382e-25+5.249982571018523e-26j),
#  (-2.686023793614703e-18+4.5077032600415136e-18j),
#  (-4.744264152326224e-09+5.873838842085328e-11j),
#  (-0.004901266067380899+0.0010785029600175573j),
#  (-0.5840603706442+0.378037723153793j),
#  (-0.003745274848743269-0.01140389887108581j),
#  (-8.576238501266843e-08-1.0417606143651007e-07j),
#  (1.7053554453525032e-13+2.8668616365701346e-12j),
#  (2.994841603952993e-12+1.3090887324568041e-12j),
#  (1.6092998267366608e-08+4.5219340983832545e-08j),
#  (0.001092403931784042-0.00029672595760758775j),
#  (-0.27869542777775375+0.14775128262456225j),
#  (-0.1169655669094314-0.3139500949015861j),
#  (0.0008053653568732125-0.0010726867683082814j),
#  (9.461835508232979e-08-1.233024420434537e-07j),
#  (-7.015260225599834e-12-3.181738892211462e-10j),
#  (1.235790792838717e-09-1.801224713523208e-09j),
#  (5.516038604493974e-06-6.145904644604718e-08j),
#  (-0.001643757603359219-0.007873791725883136j),
#  (-0.2661975655912685-0.2980440234922103j),
#  (-0.2789335545769714+0.3931444069460837j),
#  (0.011540966498055168-0.010132442310001714j),
#  (-3.39759658214668e-05+5.579280308687787e-05j),
#  (-8.852847265670152e-07-3.044027094237987e-06j),
#  (-1.1796276665592827e-05+2.994240174092093e-05j),
#  (-0.0020772128058421367+0.002697001996179051j),
#  (-0.048077141365379036-0.1570895505575076j),
#  (0.11587201021698373-0.6400818744860237j),
#  (0.12270789749844002-0.14064866601199896j),
#  (0.002619972695425258-0.0037809374359325893j),
#  (-4.283765293658377e-05-5.18876649533895e-05j),
#  (5.4973003846424326e-06-1.4384041849874169e-05j),
#  (0.0001879300002193962-4.981261253715342e-05j),
#  (-0.008743938403701168-0.006278967446021081j),
#  (-0.1285072169891342-0.18927263690444227j),
#  (0.38825504159802693-0.5895863751793936j),
#  (-0.07542778959174051+0.25232307584049024j),
#  (0.015097855918726002-0.0056548891378484685j),
#  (0.0006920035857562342+0.0003181282177226077j),
#  (-3.7645668905480535e-06+0.00040169546872481177j),
#  (0.004911588481250071+0.00036680309165034743j),
#  (0.03518275687852249+0.0955082830347733j),
#  (-0.44202294494788097-0.30926121106927945j),
#  (-0.4736900175789041-0.08248714006652882j),
#  (0.0688858790584545+0.026024532077173392j),
#  (0.001992589894820023+0.002563829706298067j),
#  (-0.00016938346405666105+0.000210611292785245j),
#  (0.0001401906830823257+0.0003140163005118781j),
#  (-0.004170150015829165-0.0014265081319046432j),
#  (-0.0470771455572597-0.08469158510108678j),
#  (-0.39558717941632787-0.39327373903745066j),
#  (-0.579439765742883+0.060493750472967706j),
#  (-0.050118799330765865+0.10797147982798168j),
#  (-0.0029722664458404365+0.008073202441160983j),
#  (-0.00015811932116071735-0.0011555596262286798j),
#  (0.001213833603046576-0.0024514676924801255j),
#  (0.017984032282766155+0.033938814950650396j),
#  (0.3306939621719944+0.12613182932820782j),
#  (0.1959054504703033+0.5880163313093728j),
#  (-0.13173444029469508-0.12125818655628992j),
#  (-0.009574848808933237+0.0041097016088858865j),
#  (0.0001221990659569632+0.0002299867052775762j),
#  (3.087943797598141e-05+2.2662865769295415e-05j),
#  (0.00022251325258100814-2.0259270176303263e-05j),
#  (-0.002088134336848053-0.009568694136732288j),
#  (-0.08324263765889234-0.20805399789981904j),
#  (-0.15480379877898337+0.6885501883835785j),
#  (-0.2452944872780308+0.03314385032745358j),
#  (-0.012733559562501887-0.0029888917231541455j),
#  (-0.00026834472450064226-0.0002933299453009989j),
#  (6.506973132103527e-05-8.755318949269235e-05j),
#  (-7.358696528833106e-05-0.0017053389886687678j),
#  (0.060026981651149905+0.04308391659451939j),
#  (0.3401412562066719-0.4892719164841567j),
#  (-0.27297860089014914+0.1094680065544202j),
#  (0.007671384257235968-0.004114501894598613j),
#  (2.0932609836016164e-05-2.109320634229138e-05j),
#  (-1.097612132782072e-07-6.459514020656176e-08j),
#  (-3.945058196943043e-08+5.333551192868404e-08j),
#  (-4.58871446281523e-06+9.740399943930111e-06j),
#  (-0.002633274412137266-0.007613969347313669j),
#  (-0.2052698714730608-0.3619490690336948j),
#  (-0.3838403831068962-0.2343200839678324j),
#  (-0.00946956654417187-0.005939702975256974j),
#  (2.6804917338686844e-06-1.7706009172148704e-05j),
#  (-6.443978992066597e-08-1.7866506202245645e-08j),
#  (4.4236460366434573e-08-1.9958925776877013e-07j),
#  (0.000232454063414932-6.932029602531901e-07j),
#  (0.046168360538057715+0.12490922024510828j),
#  (-0.40892105341286505-0.3739791465295522j),
#  (0.005931086105377002-0.006194346690521079j),
#  (-4.771605985183457e-08+5.17947266526184e-07j),
#  (6.437710591543455e-13+3.572411787957141e-14j),
#  (2.977359356259067e-17-4.2118672765037524e-17j),
#  (-9.678005953504496e-16-3.1250608708761635e-15j),
#  (5.0887782221938e-09-7.645652267978511e-09j),
#  (0.005129913980218981-0.001861365122310461j),
#  (-0.10942944628236945-0.6898046095171544j),
#  (0.0025728764847653923-0.006368835723182523j),
#  (6.311678003601315e-09-7.161808225941652e-09j),
#  (-5.952490140163782e-17+1.876312549093696e-18j),
#  (-2.335171522036257e-22-1.406162029381154e-21j),
#  (-2.4941713434623437e-18-2.2442080667948258e-17j),
#  (-6.382588843808005e-08+3.1194263853159535e-07j),
#  (0.22212348311582247-0.20277119474023989j),
#  (-0.0004442393168596749-0.007590249133889292j),
#  (7.513284701902557e-13-4.755295949342522e-12j),
#  (-3.398435986697138e-29+9.916309792013948e-29j),
#  (-1.0199737003532114e-50+7.719305677762142e-51j),
#  (-2.9041237442967953e-61-5.4952455173604294e-61j),
#  (-1.9164475400229516e-47+2.223528186211828e-48j),
#  (-5.636860058292703e-21-5.228213106879113e-21j),
#  (0.002620020364905415-0.0005280277907311159j),
#  (0.006198752370224341+0.0023549489027191598j),
#  (3.212636865386117e-20+1.2422180489150708e-20j),
#  (1.4165563202435529e-56-4.479743198727291e-56j),
#  (-7.045715099078792e-103+1.810349414693223e-102j),
#  (1.2529474293362395e-120-9.531919951641643e-121j),
#  (1.9332505081203891e-78-5.4256734879573725e-78j),
#  (4.579391648394437e-20-2.3473590675105285e-20j),
#  (0.17889922466762337+0.026820283805926798j),
#  (-2.7957981334713695e-34-5.522239154018599e-34j),
#  (2.242022550920306e-121+5.023188600413809e-120j),
#  (-2.699585051812091e-258-7.73324617798456e-259j),
#  0j,
#  (1.6270174961214876e-280+5.605934956069976e-280j),
#  (-3.788633984055364e-134-7.238362064885423e-134j),
#  (-6.08791961256941e-35+4.4308987834564304e-35j),
#  (0.44585394923092525+0.2043732291278032j),
#  (-2.994024068464279e-32+1.3715450481903228e-30j),
#  (-5.943500022019486e-109+2.7145448221953066e-109j),
#  (4.1144059983471294e-164+4.0475157792783536e-162j),
#  (-1.4212985387137136e-131+1.1802944043709417e-131j),
#  (-5.043710725045264e-69+3.3703337933753626e-69j),
#  (-4.820999744808745e-24+7.387131349683582e-24j),
#  (-0.004662312770214926-0.0029418981043257135j),
#  (0.00012812691655022694+8.98281724501206e-06j),
#  (-1.3787457492841292e-28-2.9460619509844682e-28j),
#  (1.027013020059661e-61+1.7448738883400147e-61j),
#  (-9.441545372051614e-74-5.180803119728765e-74j),
#  (-1.4112232255600094e-56+1.7969549185064835e-56j),
#  (-2.431004801465099e-31-6.707080289333068e-31j),
#  (6.190126413007147e-12+4.867238614598112e-12j),
#  (0.03060197293879995+0.010790598230487692j),
#  (-0.05914668977174782-0.03787676040126739j),
#  (-2.5097451387775875e-10-3.372553341183439e-11j),
#  (1.9875615483308406e-22+1.155331179712311e-22j),
#  (-1.6783170741570098e-26-5.852991072011231e-27j),
#  (-1.869604420586521e-20+7.005878842293103e-20j),
#  (3.444712749425637e-10-1.749321313443242e-10j),
#  (0.002523898555232758-0.0023075658119122108j),
#  (-0.5464813118771422+0.3737806009204244j),
#  (0.0021524037314447613+0.0006117518387862615j),
#  (-5.4624408499623216e-11+4.5715232818095214e-10j),
#  (5.548719031525106e-17-5.68903711725288e-19j),
#  (-1.6005078312717062e-18+3.4597375008365272e-18j),
#  (4.930308067361538e-13-1.5387461411494526e-13j),
#  (8.20872617697228e-07-8.291243641805933e-07j),
#  (0.020907691980317132+0.00481846823129198j),
#  (-0.6606614146657248+0.23248165282253308j),
#  (-0.02751211156892935+0.024166124682344248j),
#  (-1.4558302922129766e-06+7.838495264032461e-06j),
#  (1.2226429842955124e-09-1.904200554229388e-09j),
#  (-1.7959237698761444e-09-1.1344655595016317e-09j),
#  (-1.8527188628440748e-06-1.3803424629644112e-06j),
#  (-0.003421789240182038+0.0029618380956050075j),
#  (-0.3074211333585645+0.19811475165737744j),
#  (-0.2718999889291599-0.2823336664948652j),
#  (0.004373908392131707+0.0036410225555420237j),
#  (5.442721183115234e-06+5.183106891982158e-07j),
#  (3.377254377747152e-08+1.4473030386462633e-08j),
#  (-1.3346131156147447e-07+1.0226693651395097e-07j),
#  (-5.862104244715919e-05-8.581147977652675e-06j)]

# %%
plt.plot(sol.t,integration_l)

# %%
len(sol.t)
# Out:
# 200

# %%
from scipy.fft import fft
fft_ar = np.fft.fft(integration_l)
y=np.array(fft_ar).real
plt.plot(np.linspace(0,len(sol.t),len(sol.t))[:],np.abs(y[:]))
plt.title('fft driven')
# Out:
# Text(0.5, 1.0, 'fft driven')

# %%
from scipy import signal
x = signal.lfilter([1,2], 2, y)
plt.plot(np.linspace(0,len(sol.t),len(sol.t))[:],x)

# %%
n=len(sol.t)
psd = y * np.conj(y)/n
#freq = (1/(dt*n)) * np.arange(n) #frequency array
idxs_half = np.arange(1, np.floor(n/2), dtype=np.int32) #first half index

# %%
threshold = 100
psd_idxs = psd > threshold #array of 0 and 1
psd_clean = psd * psd_idxs #zero out all the unnecessary powers
fhat_clean = psd_idxs * y #used to retrieve the signal

signal_filtered = np.fft.ifft(fhat_clean) #inverse fourier transform

# %%
plt.plot(np.linspace(0,len(sol.t),len(sol.t))[:],signal_filtered)

# %%
from scipy.integrate import quad
def integrand(q,x,x0,p,p0,chi,chi0,pi,pi0, sr, si, sr0,si0):
    return (1j)*((q - x)*(pi/(2*chi) + 1j/(4/ chi**2)) *(q - x) + p*(q - x) + sr+si)*((-1j)*((q - x0)*(pi0/(2*chi0) - 1j/(4/ chi0**2)) *(q - x0) + p0*(q - x0) + sr0+si0))
def real_func(q,x,x0,p,p0,chi,chi0,pi,pi0, sr, si, sr0,si0):
        return np.real(integrand(q,x,x0,p,p0,chi,chi0,pi,pi0, sr, si, sr0,si0))
def imag_func(q,x,x0,p,p0,chi,chi0,pi,pi0, sr, si, sr0,si0):
    return np.imag(integrand(q,x,x0,p,p0,chi,chi0,pi,pi0, sr, si, sr0,si0))

# %%
integrated_l=[]
comb_ar=[]
for i in range(len(sol_ar)):
    x=sol_ar[i][0]
    x0=X[0]
    p=sol_ar[i][1]
    p0=X[1]
    chi=sol_ar[i][2]
    chi0=X[2]
    pi=sol_ar[i][3]
    pi0=X[3]
    sr=sol_ar[i][4]
    si=sol_ar[i][5]
    sr0=X[4]
    si0=X[5]
    
    
    
    real_integral = quad(real_func, -np.inf, np.inf, args=(x,x0,p,p0,chi,chi0,pi,pi0, sr, si, sr0,si0))
    imag_integral = quad(imag_func, -np.inf, np.inf, args=(x,x0,p,p0,chi,chi0,pi,pi0, sr, si, sr0,si0))
    comb_ar.append(real_integral[0] + 1j*imag_integral[0])
    #integrated_l.append(quad(integrand, -np.inf, np.inf, args=(x,x0,p,p0,chi,chi0,pi,pi0, sr, si, sr0,si0)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [80], in <cell line: 3>()
#      15 si0=X[5]
#      19 real_integral = quad(real_func, -np.inf, np.inf, args=(x,x0,p,p0,chi,chi0,pi,pi0, sr, si, sr0,si0))
# ---> 20 imag_integral = quad(imag_func, -np.inf, np.inf, args=(x,x0,p,p0,chi,chi0,pi,pi0, sr, si, sr0,si0))
#      21 comb_ar.append(real_integral[0] + 1j*imag_integral[0])
#
# File ~\anaconda3\lib\site-packages\scipy\integrate\quadpack.py:351, in quad(func, a, b, args, full_output, epsabs, epsrel, limit, points, weight, wvar, wopts, maxp1, limlst)
#     348 flip, a, b = b < a, min(a, b), max(a, b)
#     350 if weight is None:
# --> 351     retval = _quad(func, a, b, args, full_output, epsabs, epsrel, limit,
#     352                    points)
#     353 else:
#     354     if points is not None:
#
# File ~\anaconda3\lib\site-packages\scipy\integrate\quadpack.py:447, in _quad(func, a, b, args, full_output, epsabs, epsrel, limit, points)
#     445 def _quad(func,a,b,args,full_output,epsabs,epsrel,limit,points):
#     446     infbounds = 0
# --> 447     if (b != Inf and a != -Inf):
#     448         pass   # standard integration
#     449     elif (b == Inf and a != -Inf):
#
# KeyboardInterrupt:

# %%
plt.plot(sol.t,np.array(np.real(comb_ar))*10**(-69))

# %%
comb_ar

from scipy.fft import fft
fft_ar = fft(comb_ar)

# %%
y=np.array(fft_ar).real

# %%
y
# Out:
# array([-5.48529005e+69, -1.47526068e+69,  4.69255038e+69,  4.00118701e+69,
#        -2.53930876e+69, -5.36827986e+69, -3.50660269e+68,  5.17826034e+69,
#         3.13607669e+69, -3.49140065e+69, -5.01509083e+69,  7.93094045e+68,
#         5.44291648e+69,  2.13724460e+69, -4.29154288e+69, -4.44582129e+69,
#         1.89934519e+69,  5.46753210e+69,  1.04197537e+69, -4.90808846e+69,
#        -3.68447339e+69,  2.92439417e+69,  5.25782805e+69, -9.46633722e+67,
#        -5.30788338e+69, -2.76045736e+69,  3.82367641e+69,  4.81913445e+69,
#        -1.22985002e+69, -5.48115256e+69, -1.72056645e+69,  4.55403718e+69,
#         4.16995183e+69, -2.31110793e+69, -5.41421656e+69, -6.02399937e+68,
#         5.09076027e+69,  3.34309366e+69, -3.29039681e+69, -5.11264125e+69,
#         5.39756640e+68,  5.40312733e+69,  2.36724510e+69, -4.13033804e+69,
#        -4.59125253e+69,  1.65842740e+69,  5.48295871e+69,  1.29202724e+69,
#        -4.78714111e+69, -3.86711607e+69,  2.70740791e+69,  5.32530511e+69,
#         1.59177313e+68, -5.23941087e+69, -2.97912702e+69,  3.63524758e+69,
#         4.93410043e+69, -9.81287368e+68, -5.46308770e+69, -1.95894598e+69,
#         4.40923243e+69,  4.33262766e+69, -2.07642432e+69, -5.44873678e+69,
#        -8.54750765e+68,  4.98920474e+69,  3.53940838e+69, -3.08534432e+69,
#        -5.20097351e+69,  2.85197434e+68,  5.35338902e+69,  2.59511790e+69,
#        -3.95674396e+69, -4.72364669e+69,  1.41595237e+69,  5.48694245e+69,
#         1.53789848e+69, -4.65870526e+69, -4.04492955e+69,  2.48132754e+69,
#         5.37909462e+69,  4.12044945e+68, -5.15853020e+69, -3.18877328e+69,
#         3.44243230e+69,  5.04183212e+69, -7.28165085e+68, -5.43237444e+69,
#        -2.19397846e+69,  4.25252813e+69,  4.48262774e+69, -1.84071424e+69,
#        -5.47418882e+69, -1.10644687e+69,  4.87751385e+69,  3.73032162e+69,
#        -2.87040024e+69, -5.27463487e+69,  3.28527356e+67,  5.29358214e+69,
#         2.81710753e+69, -3.77661795e+69, -4.84903445e+69,  1.16692126e+69,
#         5.47614713e+69,  1.77876113e+69, -4.52023353e+69, -4.21230927e+69,
#         2.25291706e+69,  5.42483384e+69,  6.67156887e+68, -5.06461917e+69,
#        -3.39130057e+69,  3.24073900e+69,  5.13587289e+69, -4.76971894e+68,
#        -5.39322572e+69, -2.42647015e+69,  4.08613143e+69,  4.62421212e+69,
#        -1.59837480e+69, -5.48442648e+69, -1.35241521e+69,  4.75772771e+69,
#         3.91404018e+69, -2.65022824e+69, -5.33943594e+69, -2.22947097e+68,
#         5.21897553e+69,  3.03044926e+69, -3.58947852e+69, -4.96332658e+69,
#         9.17651704e+68,  5.45686727e+69,  2.01927843e+69, -4.36926604e+69,
#        -4.36926770e+69,  2.01927828e+69,  5.45686908e+69,  9.17650213e+68,
#        -4.96332706e+69, -3.58947661e+69,  3.03044802e+69,  5.21897476e+69,
#        -2.22945154e+68, -5.33943694e+69, -2.65022929e+69,  3.91404214e+69,
#         4.75772701e+69, -1.35241652e+69, -5.48442460e+69, -1.59837520e+69,
#         4.62421061e+69,  4.08613321e+69, -2.42647025e+69, -5.39322743e+69,
#        -4.76970263e+68,  5.13587313e+69,  3.24073717e+69, -3.39129915e+69,
#        -5.06461864e+69,  6.67154966e+68,  5.42483505e+69,  2.25291790e+69,
#        -4.21231123e+69, -4.52023260e+69,  1.77876223e+69,  5.47614520e+69,
#         1.16692192e+69, -4.84903310e+69, -3.77661983e+69,  2.81710786e+69,
#         5.29358372e+69,  3.28509921e+67, -5.27463484e+69, -2.87039851e+69,
#         3.73032003e+69,  4.87751356e+69, -1.10644500e+69, -5.47419020e+69,
#        -1.84071485e+69,  4.48262966e+69,  4.25252699e+69, -2.19397935e+69,
#        -5.43237249e+69, -7.28165971e+68,  5.04183095e+69,  3.44243423e+69,
#        -3.18877385e+69, -5.15853160e+69,  4.12046786e+68,  5.37909434e+69,
#         2.48132594e+69, -4.04492782e+69, -4.65870521e+69,  1.53789671e+69,
#         5.48694399e+69,  1.41595273e+69, -4.72364856e+69, -3.95674262e+69,
#         2.59511856e+69,  5.35338707e+69,  2.85198525e+68, -5.20097254e+69,
#        -3.08534627e+69,  3.53940919e+69,  4.98920594e+69, -8.54752682e+68,
#        -5.44873626e+69, -2.07642287e+69,  4.33262583e+69,  4.40923262e+69,
#        -1.95894434e+69, -5.46308938e+69, -9.81287472e+68,  4.93410222e+69,
#         3.63524606e+69, -2.97912746e+69, -5.23940896e+69,  1.59176036e+68,
#         5.32530438e+69,  2.70740985e+69, -3.86711711e+69, -4.78714211e+69,
#         1.29202921e+69,  5.48295796e+69,  1.65842612e+69, -4.59125064e+69,
#        -4.13033849e+69,  2.36724362e+69,  5.40312913e+69,  5.39756494e+68,
#        -5.11264294e+69, -3.29039515e+69,  3.34309385e+69,  5.09075846e+69,
#        -6.02398482e+68, -5.41421608e+69, -2.31110984e+69,  4.16995308e+69,
#         4.55403798e+69, -1.72056841e+69, -5.48115160e+69, -1.22984895e+69,
#         4.81913252e+69,  3.82367710e+69, -2.76045605e+69, -5.30788527e+69,
#        -9.46629886e+67,  5.25782959e+69,  2.92439240e+69, -3.68447333e+69,
#        -4.90808676e+69,  1.04197375e+69,  5.46753186e+69,  1.89934704e+69,
#        -4.44582271e+69, -4.29154345e+69,  2.13724653e+69,  5.44291531e+69,
#         7.93093201e+68, -5.01508888e+69, -3.49140157e+69,  3.13607556e+69,
#         5.17826228e+69, -3.50660882e+68, -5.36828123e+69, -2.53930690e+69,
#         4.00118669e+69,  4.69254881e+69, -1.47525893e+69])

# %%
plt.plot(np.linspace,y)

# %%
#check integral for extreme values
